# %%
import subprocess
import json
import pandas as pd

# Run the CLI script and capture output
period = "24mo"
window = 30

# !python lng_dashboard.py --period {period} --window {window}
# Out:
# === LNG Dashboard Run Complete ===
# Period: 24mo
# Rolling Vol Window: 30 days

# %% [markdown]
# ## Daily LNG Market Note — {{ date }}
#
# ### 🔹 Key Moves
# - JKM:
# - TTF:
# - NBP:
# - Brent:
#
# ### 🔹 Spreads
# - JKM–TTF:
# - JKM–NBP:
# - TTF–NBP:
#
# ### 🔹 Volatility
# - Highest vol:
# - Notable shifts:
#
# ### 🔹 Trading Implications
# -
